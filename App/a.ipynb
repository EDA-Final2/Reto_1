# %%
a = 1
b = 2

# %%
# a = b
# b = a
# a, b
a, b = b, a
a, b
# Out:
# (2, 1)

# %%
import pandas as pd

# %%
archivo = '../Data/spotify-albums-utf8-small.csv'
pd.read_csv(archivo)
# Out:
#                          id                track_id  total_tracks  \
# 0    4sDAyYEMhD2YyREWKxj3aD  3bsycjdQtbcJeR6822SBvd          13.0
# 1    2vtXlIjsYPW5LiblMjIDBi  0Uub8OPsm8ojFRInBJxXyH           6.0
# 2    46BSjIgwm2NarXXFM8fEjX  1tKAI8igKXPqovihv4Px57          10.0
# 3    0rdtx9JOcYikLL8zKRnvYd  4HM8clsA4Pt47K4ENgJlo3          25.0
# 4    3cULhf4xVD4KHDheoCTZWV  5VZm7niwhFF7EJRa4vD3zA          15.0
# ..                      ...                     ...           ...
# 684  1RnKnR16T9sWJlxCgWla1i  1uMJkxQipn0Mm0cAoctX82           1.0
# 685  02tfQwJSOLP77oCd9U8bqm  39lSeqnyjZJejRuaREfyLL          29.0
# 686  6ANCHHVpcvjCqQFUDUvDOW  2oeLt7N1amHZiev27FvKE2          15.0
# 687  3mrBObrvXLr3HvqSYdTilG  1z5kvdG3vjMUpJsNt76JVf           1.0
# 688  29vo83aZt4XUt2gUSAxzwg  4XbAHiP83NvAj1rW2vIrys           8.0
#
#                                          external_urls   album_type  \
# 0    {'spotify': 'https://open.spotify.com/album/4s...        album
# ...
